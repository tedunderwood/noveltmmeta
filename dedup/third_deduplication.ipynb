# %% [markdown]
# # Third deduplication
#
# A final standardizing pass on **workmeta**, followed by a temporal filter to produce **contemporaryworkmeta**.

# %%
import pandas as pd

# %%
work = pd.read_csv('newworkmeta.tsv', sep = '\t', low_memory = False)

# %% [markdown]
# ### Standardize names
#
# In our second deduplication notebook, we wrote to file pairs of names that we discovered in the process of deduplicating works. The texts and titles of certain works were similar enough to convince us that these author names were also equivalent.
#
# However, we don't know which name is better. To decide, we need some rules, which I will proceed to provide.

# %%
authsets = pd.read_csv('authorsets.tsv', sep = '\t', header = None, names = ['name1', 'name2'])
authsets.head()
# Out:
#                               name1                                      name2
# 0           Robinson, Mary Stephens                           Robinson, Mary S
# 1                Howes, Edith Annie                               Howes, Edith
# 2  Williams, Elizabeth Whitney, Mrs                Williams, Elizabeth Whitney
# 3   Somerville, E. Œ. (Edith Œnone)  Somerville, E. &#xbf;. (Edith &#xbf;none)
# 4                      Pearce, Donn                             Pearce, Donald

# %%
def name2prefer(row):
    ''' A bunch of rules we can use to make up our mind.
    Basically, diacritical marks are preferred to garbage
    equivalents; otherwise longer forms are usually preferred.
    '''
    option1 = row.name1
    option2 = row.name2
    if '??' in option1 or '#xbf;' in option1:
        return option2
    elif '??' in option2 or '#xbf;' in option2:
        return option1
    elif 'from old catalog' in option1:
        return option2
    elif 'from old catalog' in option2:
        return option1
    elif '?_' in option1:
        return option2
    elif '?_' in option2:
        return option1
    elif ' ̌' in option1:
        return option2
    elif ' ̌' in option2:
        return option1
    elif '1' in option1:
        return option2
    elif '1' in option2:
        return option1
    elif '  ' in option1:
        return option2
    elif '  ' in option2:
        return option1
    elif 'è' in option1 or 'é' in option1:
        return option1
    elif 'è' in option2 or 'é' in option2:
        return option2
    elif len(option1) > len(option2):
        return option1
    else:
        return option2

authsets = authsets.assign(normative = authsets.apply(name2prefer, axis = 1))
authsets.head()
# Out:
#                               name1  \
# 0           Robinson, Mary Stephens
# 1                Howes, Edith Annie
# 2  Williams, Elizabeth Whitney, Mrs
# 3   Somerville, E. Œ. (Edith Œnone)
# 4                      Pearce, Donn
#
#                                        name2                         normative
# 0                           Robinson, Mary S           Robinson, Mary Stephens
# 1                               Howes, Edith                Howes, Edith Annie
# 2                Williams, Elizabeth Whitney  Williams, Elizabeth Whitney, Mrs
# 3  Somerville, E. &#xbf;. (Edith &#xbf;none)   Somerville, E. Œ. (Edith Œnone)
# 4                             Pearce, Donald                    Pearce, Donald

# %% [markdown]
# #### now actually make the change

# %%
firstset = set(authsets.name1)
secondset = set(authsets.name2)
ctr = 0

def applynorm(name):
    global firstset, secondset, authsets, ctr
    
    if name in firstset:
        newname = str(authsets.loc[authsets.name1 == name, 'normative'].values[0])
        ctr += 1
        return newname
    elif name in secondset:
        newname = str(authsets.loc[authsets.name2 == name, 'normative'].values[0])
        ctr += 1
        return newname
    else:
        return name
    
work = work.assign(author = work.author.map(applynorm))  
print(ctr)
# Out:
# 2899

# %% [markdown]
# That change was made in 2899 rows.

# %% [markdown]
# ### Correct authordates
#
# An error in an earlier notebook has caused the author "blank" or "no author name provided" to inherit authordates. These are not real.

# %%
ctr = 0

def be_agnostic(row):
    global ctr
    
    if pd.isnull(row.author) or len(row.author) < 2:
        ctr += 1
        return ''
    else:
        return row.authordate

work = work.assign(authordate = work.apply(be_agnostic, axis = 1))
print('Change made in ' + str (ctr) + ' rows.')
# Out:
# Change made in 8553 rows.

# %% [markdown]
# ### Update last date of composition
#
# We have a column **lastcomp** that's supposed to contain an inference about the last possible date of composition, based on certain values of **datetype** and **enddate,** plus authors' death dates.
#
# But the dates of death have been updated since **lastcomp** was created. We may be able to improve that column a little before using it in the next stage of dedup.

# %%
ctr = 0

def update(row):
    global ctr 
    
    lastcomp = row.latestcomp
    if pd.isnull(lastcomp):
        lastcomp = float('nan')
    else:
        lastcomp = int(lastcomp)
        
    authordates = str(row.authordate).strip('[.]() ')
    
    if pd.isnull(authordates):
        if pd.isnull(lastcomp) or lastcomp > 2010:
            return float('nan')
        else:
            return lastcomp
        
    elif authordates.startswith('d.') or (len(authordates) > 7 and '-' in authordates):
        try:
            death = int(authordates[-4 : ])
        except:
            death = 0
    else:
        death = 0
    
    if (death > 1500 and death < 2010) and death < lastcomp:
        ctr += 1
        return death
    else:
        return lastcomp

work = work.assign(updated = work.apply(update, axis = 1))
print('Change made in ' + str (ctr) + ' rows.')
# Out:
# Change made in 1927 rows.

# %%
work['latestcomp'] = work['updated']
work.drop(labels = ['updated'], axis = 1, inplace = True)

# %%
def whethertokeep(row):
    infdate = int(row.inferreddate)
    lastcomp = row.latestcomp
    if pd.isnull(lastcomp):
        return True
    else:
        lastcomp = int(lastcomp)
    
    if infdate > (lastcomp + 25):
        return False
    else:
        return True

work = work.assign(earlyedition = work.apply(whethertokeep, axis = 1))

# %%
work.loc[work.author.str.startswith('Gaskell, E', na = False), : ]
# Out:
#                             docid                    oldauthor  \
# 249            nyp.33433074857115  Gaskell, Elizabeth Cleghorn
# 8947    uiuo.ark+=13960=t9z03hc07  Gaskell, Elizabeth Cleghorn
# 10281          njp.32101019691409  Gaskell, Elizabeth Cleghorn
# 10426          nyp.33433074857149  Gaskell, Elizabeth Cleghorn
# 10427          nyp.33433074857131  Gaskell, Elizabeth Cleghorn
# 11082          nyp.33433074857362  Gaskell, Elizabeth Cleghorn
# 12045          nyp.33433082340302  Gaskell, Elizabeth Cleghorn
# 12064          nyp.33433074857156  Gaskell, Elizabeth Cleghorn
# 12236          inu.30000007412517  Gaskell, Elizabeth Cleghorn
# 12364                uc1.b3322505  Gaskell, Elizabeth Cleghorn
# 12365                uc1.b3322506  Gaskell, Elizabeth Cleghorn
# 12808          nyp.33433074857503  Gaskell, Elizabeth Cleghorn
# 13408                uc1.b4105357  Gaskell, Elizabeth Cleghorn
# 13504          nyp.33433074857354  Gaskell, Elizabeth Cleghorn
# 13598   uiuo.ark+=13960=t8jd57r2q  Gaskell, Elizabeth Cleghorn
# 13599   uiuo.ark+=13960=t43r17n3n  Gaskell, Elizabeth Cleghorn
# 13600   uiuo.ark+=13960=t6057xr4s  Gaskell, Elizabeth Cleghorn
# 13718                uc1.b3548115  Gaskell, Elizabeth Cleghorn
# 14108    uc2.ark+=13960=t4sj1k525  Gaskell, Elizabeth Cleghorn
# 14747   dul1.ark+=13960=t6d22nv15  Gaskell, Elizabeth Cleghorn
# 14748   dul1.ark+=13960=t5r792w66  Gaskell, Elizabeth Cleghorn
# 116633  Gaskell, Elizabeth Cleghorn  1810-1865.          1992        1865
# 118310  Gaskell, Elizabeth Cleghorn  1810-1865.          1993        1865
# 130095  Gaskell, Elizabeth Cleghorn  1810-1865.          2003        1865
# 133660  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133661  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133662  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133663  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133664  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133665  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
# 133666  Gaskell, Elizabeth Cleghorn  1810-1865.          2005        1865
#
#        datetype startdate enddate  \
# 249           n      uuuu    uuuu
# 8947          s      1848
# 10281         s      1853
# 10426         s      1853
# 10427         s      1853
# 11082         s      1855
# 12045         s      1858
# 12064         s      1858
# 12236         s      1859
# 12364         s      1859
# 12365         s      1859
# 12808         s      1860
# 13408         s      1863
# 13504         s      1863
# 13598         s      1863
# 13599         s      1863
# 13600         s      1863
# 13718         s      1864
# 14108         s      1865
# 14747         s      1866
# 14748         s      1866
# 23374         s      1886
# 25113         s      1889
# 25931         s      1890
# 26081         s      1890
# 27268         s      1891
# 30045         s      1895
# 38368         s      1902
# 42927         m      1906    1911
# 42928         m      1906    1911
# ...         ...       ...     ...
# 95616         s      1971
# 96151         r      1972    1906
# 96340         r      1972    1906
# 96341         r      1972    1906
# 96342         r      1972    1906
# 96343         r      1972    1906
# 96344         r      1972    1906
# 96345         r      1972    1906
# 96438         s      1972
# 96439         s      1972
# 96440         s      1972
# 96441         s      1972
# 96442         s      1972
# 96517         r      1972
# 96643         r      1972    1906
# 96646         r      1972    1906
# 96671         r      1972    1906
# 101596        s      1978
# 106282        s      1983
# 108347        s      1985
# 116633        s      1992
# 118310        s      1993
# 130095        s      2003
# 133660        m      2005    9999
# 133661        m      2005    9999
# 133662        m      2005    9999
# 133663        m      2005    9999
# 133664        m      2005    9999
# 133665        m      2005    9999
# 133666        m      2005    9999
#
#                                                   imprint      ...       \
# 249                                    New York|Dodd|n.d.      ...
# 8947                        London;Chapman and Hall;1848.      ...
# 10281                    New York;Harper & brothers;1853.      ...
# 10426                          Leipzig;B. Tauchnitz;1853.      ...
# 10427                          Leipzig;B. Tauchnitz;1853.      ...
# 11082                       New York;Harper & Bros.;1855.      ...
# 12045                             New York;Appleton;1858.      ...
# 12064                               New York;Harper;1858.      ...
# 12236                      London;S. Low, son & co.;1859.      ...
# 12364                                 London;S. Low;1859.      ...
# 12365                                 London;S. Low;1859.      ...
# 12808                    New York;Harper & Brothers;1860.      ...
# 13408                           London;Smith, Elder;1863.      ...
# 13504                               New York;Harper;1863.      ...
# 13598                    London;Smith, Elder, & Co.;1863.      ...
# 13599                    London;Smith, Elder, & Co.;1863.      ...
# 13600                    London;Smith, Elder, & Co.;1863.      ...
# 13718                               New York;Harper;1864.      ...
# 14108                   London;Smith, Elder and Co.;1865.      ...
# 14747                    London;Smith, Elder and Co;1866.      ...
# 14748                    London;Smith, Elder and Co;1866.      ...
# 23374   London;Smith, Elder, & Co.;1886;(London;Printe...      ...
# 25113                     London;Smith, Elder & co.;1889.      ...
# 25931                           London;Smith, Elder;1890.      ...
# 26081                            London;Smith, Elder;1890      ...
# 27268                                          n.p.;c1891      ...
# 30045                   Chicago;A. C. McClurg & co.;1895.      ...
# 38368                    London;Smith, Elder, & co.;1902.      ...
# 42927                      London;Smith, Elder;1906-1911.      ...
# 42928                      London;Smith, Elder;1906-1911.      ...
# ...                                                   ...      ...
# 95616     Freeport, N.Y.|Books for Libraries Press|1971].      ...
# 96151                            New York|AMS Press|1972.      ...
# 96340                            New York|AMS Press|1972.      ...
# 96341                            New York|AMS Press|1972.      ...
# 96342                            New York|AMS Press|1972.      ...
# 96343                            New York|AMS Press|1972.      ...
# 96344                            New York|AMS Press|1972.      ...
# 96345                            New York|AMS Press|1972.      ...
# 96438                           New York|AMS Press|1972].      ...
# 96439                           New York|AMS Press|1972].      ...
# 96440                           New York|AMS Press|1972].      ...
# 96441                           New York|AMS Press|1972].      ...
# 96442                           New York|AMS Press|1972].      ...
# 96517       Freeport, N.Y.|Books for Libraries Press|1972      ...
# 96643                             New York|AMS Press|1972      ...
# 96646                             New York|AMS Press|1972      ...
# 96671                             New York|AMS Press|1972      ...
# 101596                              London|Gollancz|1978.      ...
# 106282                  London|Boston|Pandora Press|1983.      ...
# 108347        Gloucester [Gloucestershire|A. Sutton|1985.      ...
# 116633      Oxford|New York|Oxford University Press|1992.      ...
# 118310                          Halifax|Ryburn Pub.|1993.      ...
# 130095                              London|Hesperus|2003.      ...
# 133660                    London|Pickering & Chatto|2005-      ...
# 133661                    London|Pickering & Chatto|2005-      ...
# 133662                    London|Pickering & Chatto|2005-      ...
# 133663                    London|Pickering & Chatto|2005-      ...
# 133664                    London|Pickering & Chatto|2005-      ...
# 133665                    London|Pickering & Chatto|2005-      ...
# 133666                    London|Pickering & Chatto|2005-      ...
#
#          recordid instances allcopiesofwork copiesin25yrs enumcron volnum  \
# 249       8665158         1               1             1      NaN    NaN
# 8947      1419882         1               8             1      v.1    1.0
# 10281     1419868         1              35             2      NaN    NaN
# 10426     8665214         1               6             6     v. 1    1.0
# 10427     8665214         1               6             6     v. 2    2.0
# 11082     8668329         1              13             4      NaN    NaN
# 12045     8637302         1               1             1   v. 1-2    1.0
# 12064     8665192         1               2             2      NaN    NaN
# 12236     6059946         1               3             1      v.1    1.0
# 12364     7915307         1               1             1      v.1    1.0
# 12365     7915307         1               1             1     v. 2    2.0
# 12808     8682265         1               2             1      NaN    NaN
# 13408     6156256         1               1             1      NaN    NaN
# 13504     8665241         1               1             1      NaN    NaN
# 13598     8723650         1              13             4      v.1    1.0
# 13599     8723650         1              13             4      v.2    2.0
# 13600     8723650         1              13             4      v.3    3.0
# 13718     6672535         1               1             1      NaN    NaN
# 14108     7915306         2               2             2      NaN    NaN
# 14747    10945320         1               7             3      v.1    1.0
# 14748    10945320         1               7             3      v.2    2.0
# 23374     8665294         1               6             4     v. 4    4.0
# 25113     6155755         1               1             1      NaN    NaN
# 25931     7031197         1               5             3      NaN    NaN
# 26081     7695395         1               1             1      NaN    NaN
# 27268    11207487         1               1             1      NaN    NaN
# 30045      326041         2               2             2      NaN    NaN
# 38368     1419887         1               4             3      NaN    NaN
# 42927     6674007         1               4             4      v.5    5.0
# 42928     6674007         1               4             4      v.7    7.0
# ...           ...       ...             ...           ...      ...    ...
# 95616     7039431         1               1             1      NaN    NaN
# 96151     1098589         1               2             2      v.5    5.0
# 96340     4454040         1               1             1      v.3    3.0
# 96341     4454040         1               1             1      v.4    4.0
# 96342     4454040         1               1             1      v.5    5.0
# 96343     4454040         1               1             1      v.6    6.0
# 96344     4454040         1               1             1      v.7    7.0
# 96345     4454040         1               1             1      v.8    8.0
# 96438     7063414         1               1             1      v.4    4.0
# 96439     7063414         1               1             1      v.5    5.0
# 96440     7063414         1               1             1      v.6    6.0
# 96441     7063414         1               1             1      v.7    7.0
# 96442     7063414         1               1             1      v.8    8.0
# 96517     8323001         1               1             1      NaN    NaN
# 96643    10882912         1               1             1      NaN    NaN
# 96646    11719443         1               1             1      NaN    NaN
# 96671   100115835         1               1             1      NaN    NaN
# 101596     219234         1               2             2      NaN    NaN
# 106282     242460         1               1             1      NaN    NaN
# 108347     832657         1               1             1      NaN    NaN
# 116633    3595059         1               1             1      NaN    NaN
# 118310    9925223         2               2             2      NaN    NaN
# 130095    4325784         1               1             1      NaN    NaN
# 133660    7586087         1               1             1      v.2    2.0
# 133661    7586087         2               9             9      v.3    3.0
# 133662    7586087         2               9             9      v.4    4.0
# 133663    7586087         2               9             9      v.5    5.0
# 133664    7586087         2               9             9      v.7    7.0
# 133665    7586087         1               9             9      v.9    9.0
# 133666    7586087         2               2             2     v.10   10.0
#
#                                                     title  \
# 249     Cranford, | with a memoir of the author; | $c:...
# 8947                                          Mary Barton
# 10281   Cranford / | $c: by the author of "Mary Barton...
# 10426   Ruth : | a novel / | $c: by the author of "Mar...
# 10427   Ruth : | a novel / | $c: by the author of "Mar...
# 11082   North and south, | $c: by the author of Mary B...
# 12045   The life of Charlotte Brontë / | $c: by E. C....
# 12064   My Lady Ludlow : | a novel / | $c: by Mrs. Gas...
# 12236   Round the sofa. | $c: By the author of "Mary B...
# 12364   Round the sofa / | $c: by the author of "Mary ...
# 12365   Round the sofa / | $c: by the author of "Mary ...
# 12808   Right at last, and other tales. | $c: By Mrs. ...
# 13408                                A dark night's work.
# 13504   Sylvia's lovers : | a novel / | $c: by Mrs. Ga...
# 13598                                     Sylvia's lovers
# 13599                                     Sylvia's lovers
# 13600                                     Sylvia's lovers
# 13718                          Cousin Phillis : | a tale.
# 14108                                      Cousin Phillis
# 14747                                 Wives and daughters
# 14748                                 Wives and daughters
# 23374   Cranford and other tales / | $c: by Mrs. Gaskell.
# 25113   Lizzie Leigh, | and other tales, | $c: By Mrs....
# 25931       Ruth and other tales / | $c: by Mrs. Gaskell.
# 26081                 A dark night's work and other tales
# 27268                Life of Charlotte Bront??, condensed
# 30045   Cousin Phillis : | a story of English love / |...
# 38368   Mary Barton and other tales, | $c: by Mrs. Gas...
# 42927      Works; | $c: with introductions by A. W. Ward.
# 42928      Works; | $c: with introductions by A. W. Ward.
# ...                                                   ...
# 95616                    The grey woman, and other tales.
# 96151   The works of Mrs. Gaskell in eight volumes / |...
# 96340   The works of Mrs. Gaskell in eight volumes / |...
# 96341   The works of Mrs. Gaskell in eight volumes / |...
# 96342   The works of Mrs. Gaskell in eight volumes / |...
# 96343   The works of Mrs. Gaskell in eight volumes / |...
# 96344   The works of Mrs. Gaskell in eight volumes / |...
# 96345   The works of Mrs. Gaskell in eight volumes / |...
# 96438   The works of Mrs. Gaskell : | With a general b...
# 96439   The works of Mrs. Gaskell : | With a general b...
# 96440   The works of Mrs. Gaskell : | With a general b...
# 96441   The works of Mrs. Gaskell : | With a general b...
# 96442   The works of Mrs. Gaskell : | With a general b...
# 96517                      Lizzie Leigh, and other tales.
# 96643   Cousin Phillis. | To which are added: Lois the...
# 96646   Sylvia's lovers. | To which is added An Italia...
# 96671   Ruth. | To which have been added: Cumberland s...
# 101596  Mrs Gaskell's tales of mystery and horror / | ...
# 106282  Four short stories / | $c: Elizabeth Gaskell ;...
# 108347         The Manchester marriage and other stories.
# 116633  A dark night's work, and other stories / | $c:...
# 118310  Mary Barton : | a tale of Manchester life / | ...
# 130095          Lois the witch / | $c: Elizabeth Gaskell.
# 133660  The works of Elizabeth Gaskell / | $c: general...
# 133661  The works of Elizabeth Gaskell / | $c: general...
# 133662  The works of Elizabeth Gaskell / | $c: general...
# 133663  The works of Elizabeth Gaskell / | $c: general...
# 133664  The works of Elizabeth Gaskell / | $c: general...
# 133665  The works of Elizabeth Gaskell / | $c: general...
# 133666  The works of Elizabeth Gaskell / | $c: general...
#
#                                                 parttitle  \
# 249                                                   NaN
# 8947                                                  NaN
# 10281                                                 NaN
# 10426                                                 NaN
# 10427                                                 NaN
# 11082                                                 NaN
# 12045                                                 NaN
# 12064                                                 NaN
# 12236                                                 NaN
# 12364                      Round the sofa. My Lady Ludlow
# 12365   The accursed race. The doom of the Griffiths. ...
# 12808                                                 NaN
# 13408                                                 NaN
# 13504                                                 NaN
# 13598                                                 NaN
# 13599                                                 NaN
# 13600                                                 NaN
# 13718                                                 NaN
# 14108                                                 NaN
# 14747                                                 NaN
# 14748                                                 NaN
# 23374                                                 NaN
# 25113                                                 NaN
# 25931                                                 NaN
# 26081                                                 NaN
# 27268                                                 NaN
# 30045                                                 NaN
# 38368                                                 NaN
# 42927                     My lady Ludlow, and other tales
# 42928                     Cousin Phillis, and other tales
# ...                                                   ...
# 95616                                                 NaN
# 96151                                      My Lady Ludlow
# 96340                                                 NaN
# 96341                                                 NaN
# 96342                                                 NaN
# 96343                                                 NaN
# 96344                                                 NaN
# 96345                                                 NaN
# 96438                                 Wives and daughters
# 96439                                                 NaN
# 96440                                                 NaN
# 96441                                                 NaN
# 96442                                                 NaN
# 96517                                                 NaN
# 96643                                                 NaN
# 96646                                                 NaN
# 96671                                                 NaN
# 101596                                                NaN
# 106282                                                NaN
# 108347                                                NaN
# 116633                                                NaN
# 118310                                                NaN
# 130095                                                NaN
# 133660  Novellas and shorter fiction, The Moorland Cot...
# 133661  and William Gaskell, two lectures on the Lanca...
# 133662  and William Gaskell, two lectures on the Lanca...
# 133663  and William Gaskell, two lectures on the Lanca...
# 133664  and William Gaskell, two lectures on the Lanca...
# 133665  and William Gaskell, two lectures on the Lanca...
# 133666                                                NaN
#
#                                                shorttitle  earlyedition
# 249                Cranford, with a memoir of the author;          True
# 8947                                          Mary Barton          True
# 10281                                            Cranford          True
# 10426                                      Ruth : a novel          True
# 10427                                      Ruth : a novel          True
# 11082                                     North and south          True
# 12045                       The life of Charlotte Brontë          True
# 12064                            My Lady Ludlow : a novel          True
# 12236                                      Round the sofa          True
# 12364                      Round the sofa. My Lady Ludlow          True
# 12365   The accursed race. The doom of the Griffiths. ...          True
# 12808                      Right at last, and other tales          True
# 13408                                 A dark night's work          True
# 13504                           Sylvia's lovers : a novel          True
# 13598                                     Sylvia's lovers          True
# 13599                                     Sylvia's lovers          True
# 13600                                     Sylvia's lovers          True
# 13718                             Cousin Phillis : a tale          True
# 14108                                      Cousin Phillis          True
# 14747                                 Wives and daughters          True
# 14748                                 Wives and daughters          True
# 23374                            Cranford and other tales          True
# 25113                       Lizzie Leigh, and other tales          True
# 25931                                Ruth and other tales          True
# 26081                 A dark night's work and other tales          True
# 27268                Life of Charlotte Bront??, condensed         False
# 30045            Cousin Phillis : a story of English love         False
# 38368                         Mary Barton and other tales         False
# 42927                     My lady Ludlow, and other tales         False
# 42928                     Cousin Phillis, and other tales         False
# ...                                                   ...           ...
# 95616                     The grey woman, and other tales         False
# 96151                                      My Lady Ludlow         False
# 96340          The works of Mrs. Gaskell in eight volumes         False
# 96341          The works of Mrs. Gaskell in eight volumes         False
# 96342          The works of Mrs. Gaskell in eight volumes         False
# 96343          The works of Mrs. Gaskell in eight volumes         False
# 96344          The works of Mrs. Gaskell in eight volumes         False
# 96345          The works of Mrs. Gaskell in eight volumes         False
# 96438                                 Wives and daughters         False
# 96439   The works of Mrs. Gaskell : With a general bio...         False
# 96440   The works of Mrs. Gaskell : With a general bio...         False
# 96441   The works of Mrs. Gaskell : With a general bio...         False
# 96442   The works of Mrs. Gaskell : With a general bio...         False
# 96517                       Lizzie Leigh, and other tales         False
# 96643   Cousin Phillis. To which are added: Lois the W...         False
# 96646   Sylvia's lovers. To which is added An Italian ...         False
# 96671   Ruth. To which have been added: Cumberland she...         False
# 101596          Mrs Gaskell's tales of mystery and horror         False
# 106282                                 Four short stories         False
# 108347          The Manchester marriage and other stories         False
# 116633             A dark night's work, and other stories         False
# 118310            Mary Barton : a tale of Manchester life         False
# 130095                                     Lois the witch         False
# 133660  Novellas and shorter fiction, The Moorland Cot...         False
# 133661  and William Gaskell, two lectures on the Lanca...         False
# 133662  and William Gaskell, two lectures on the Lanca...         False
# 133663  and William Gaskell, two lectures on the Lanca...         False
# 133664  and William Gaskell, two lectures on the Lanca...         False
# 133665  and William Gaskell, two lectures on the Lanca...         False
# 133666                     The works of Elizabeth Gaskell         False
#
# [67 rows x 28 columns]

# %%
sum(work.earlyedition)
# Out:
# 129023

# %%
work.to_csv('../workmeta.tsv', sep = '\t', index = False)

# %% [markdown]
# ### Also correct authordate error in manifestationmeta
#
# Same error we corrected above.

# %%
manifest = pd.read_csv('../manifestationmeta.tsv', sep = '\t', low_memory = False)

# %%
ctr = 0
manifest = manifest.assign(authordate = manifest.apply(be_agnostic, axis = 1))
print('Change made in ' + str (ctr) + ' rows.')
# Out:
# Change made in 8553 rows.

# %%
manifest.to_csv('../manifestationmeta.tsv', sep = '\t', index = False)
