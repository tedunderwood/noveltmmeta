# %% [markdown]
# ## Spot checking results
#
# Just what the title says.

# %%
import pandas as pd

# %%
master = pd.read_csv('../masterficmetadata.tsv', sep = '\t', low_memory = False)
manifest = pd.read_csv('../manifestationmeta.tsv', sep = '\t', low_memory = False)
work = pd.read_csv('../workmeta.tsv', sep = '\t', low_memory = False)

# %%
mastergask = master.loc[master.shorttitle.str.startswith('Mary Barto', na = False)]
mastergask.shape
# Out:
# (14, 24)

# %%
mastergask
# Out:
#                             docid                    oldauthor  \
# 13647   uiuo.ark+=13960=t9z03hc07  Gaskell, Elizabeth Cleghorn
# 62984          mdp.39015033170104  Gaskell, Elizabeth Cleghorn
# 71863                uc1.b3556239  Gaskell, Elizabeth Cleghorn
# 72589          nyp.33433074857206  Gaskell, Elizabeth Cleghorn
# 72916          mdp.39076001556153  Gaskell, Elizabeth Cleghorn
# 83916          mdp.39015005238822  Gaskell, Elizabeth Cleghorn
# 114114         mdp.39015003699728  Gaskell, Elizabeth Cleghorn
# 142427         uc1.32106001936480  Gaskell, Elizabeth Cleghorn
# 150080         mdp.39015005216794  Gaskell, Elizabeth Cleghorn
# 150081         mdp.39015005240778  Gaskell, Elizabeth Cleghorn
# 157699         mdp.39015014540168  Gaskell, Elizabeth Cleghorn
# 158129           pst.000028738220  Gaskell, Elizabeth Cleghorn
# 187412         coo.31924077744807  Gaskell, Elizabeth Cleghorn
# 187413         mdp.39076002071061  Gaskell, Elizabeth Cleghorn
#
# ...

# %%
manifestgask = manifest.loc[manifest.shorttitle.str.startswith('Mary Barto', na = False)]
manifestgask.shape
# Out:
# (12, 25)

# %%
manifestgask
# Out:
#                             docid                    oldauthor  \
# 11950   uiuo.ark+=13960=t9z03hc07  Gaskell, Elizabeth Cleghorn
# 52525          mdp.39015033170104  Gaskell, Elizabeth Cleghorn
# 59407                uc1.b3556239  Gaskell, Elizabeth Cleghorn
# 59976          nyp.33433074857206  Gaskell, Elizabeth Cleghorn
# 60289          mdp.39076001556153  Gaskell, Elizabeth Cleghorn
# 68664          mdp.39015005238822  Gaskell, Elizabeth Cleghorn
# 91994          mdp.39015003699728  Gaskell, Elizabeth Cleghorn
# 115358         uc1.32106001936480  Gaskell, Elizabeth Cleghorn
# 121772         mdp.39015005216794  Gaskell, Elizabeth Cleghorn
# 128344         mdp.39015014540168  Gaskell, Elizabeth Cleghorn
# 128715           pst.000028738220  Gaskell, Elizabeth Cleghorn
# 155001         coo.31924077744807  Gaskell, Elizabeth Cleghorn
#
#                              author  authordate  inferreddate  latestcomp  \
# ...

# %%
workgask = work.loc[work.shorttitle.str.startswith('Mary Barto', na = False)]
workgask.shape
# Out:
# (3, 27)

# %%
workgask
# Out:
#                             docid                    oldauthor  \
# 8581    uiuo.ark+=13960=t9z03hc07  Gaskell, Elizabeth Cleghorn
# 36264          mdp.39015033170104  Gaskell, Elizabeth Cleghorn
# 115348         coo.31924077744807  Gaskell, Elizabeth Cleghorn
#
#                              author  authordate  inferreddate  latestcomp  \
# 8581    Gaskell, Elizabeth Cleghorn  1810-1865.          1848        1848
# 36264   Gaskell, Elizabeth Cleghorn  1810-1865.          1902        1865
# 115348  Gaskell, Elizabeth Cleghorn  1810-1865.          1993        1865
#
#        datetype startdate enddate                           imprint  \
# 8581          s      1848             London;Chapman and Hall;1848.
# 36264         s      1902          London;Smith, Elder, & co.;1902.
# 115348        s      1993                 Halifax|Ryburn Pub.|1993.
#
#                          ...                    place recordid instances  \
# ...

# %%
workgask = work.loc[work.author.str.startswith('Gaskell, Mrs', na = False)]
workgask.shape
# Out:
# (0, 27)

# %%
nwork = pd.read_csv('newworkmeta.tsv', sep = '\t', low_memory = False)

# %%
print(len(work.docid))
workdocs = set(work.docid)
print(len(workdocs))
print()
newdocs = set(nwork.docid)
print(len(newdocs))
# Out:
# 135299
# 135255
#
# 138137

# %%
print(len(workdocs - newdocs))
print(len(newdocs - workdocs))
# Out:
# 6627
# 9509

# %%
newthings = newdocs - workdocs
ctr = 0
nwork.set_index('docid', inplace = True)
for o in newthings:
    print(nwork.loc[o, 'shorttitle'], nwork.loc[o, 'author'])
    ctr += 1
    if ctr > 10:
        break
# Out:
# Soldiers three Kipling, Rudyard
# Sir Roger de Coverley papers from "The Spectator," Addison, Joseph
# Barbara's history Edwards, Amelia Ann Blanford
# The golden calf Braddon, M. E. (Mary Elizabeth)
# A president is born Hurst, Fannie
# The works of Charles Dickens Dickens, Charles
# [Works] Reade, Charles
# Complete works Conrad, Joseph
# Bulwer's novels Lytton, Edward Bulwer Lytton, Baron
# The works of Tobias Smollett Smollett, T. (Tobias)
# Short stories of the tragedy and comedy of life Maupassant, Guy de

# %%
oldthings = workdocs - newdocs
ctr = 0

for o in oldthings:
    print(work.loc[o, 'shorttitle'], work.loc[o, 'author'])
    ctr += 1
    if ctr > 10:
        break
# Out:
# King--of the Khyber rifles : a romance of adventure Mundy, Talbot
# Emma Austen, Jane
# Secret memoirs of Princess Lamballe; being her journals, letters and conversations during her confidential relations with Marie Antoinette princesse de Lamballe, Lamballe, Marie Thérèse Louise de Savoie-Carignan
# 99 fables March, William
# Progress and prejudice Gore, (Catherine Grace Frances), Mrs
# The abyss Sperber, Manès
# Joshua Haggard's daughter; a novel Braddon, M. E. (Mary Elizabeth)
# The Vortex family Métellus, Jean
# The desultory man James, G. P. R. (George Payne Rainsford)
# Alberta & Jacob Sandel, Cora
# Dred ; a tale of the great Dismal Swamp Stowe, Harriet Beecher

# %%
work.loc[work.shorttitle.str.startswith('King--of the Khy', na = False)]
# Out:
#                     oldauthor         author  authordate  inferreddate  \
# docid
# uva.x000279479  Mundy, Talbot  Mundy, Talbot  1879-1940.          1916
#
#                 latestcomp datetype startdate enddate  \
# docid
# uva.x000279479        1916        s      1916
#
#                                                      imprint imprintdate  \
# docid
# uva.x000279479  Indianapolis;The Bobbs-Merrill company;c1916        1916
#
#                                       ...                         place  \
# docid                                 ...
# uva.x000279479                        ...                           inu
#
#                recordid instances allcopiesofwork copiesin25yrs  enumcron  \
# docid
# uva.x000279479  9777306         1               2             2       NaN
#
#                volnum                                              title  \
# docid
# uva.x000279479    NaN  King--of the Khyber rifles : | a romance of ad...
#
# ...

# %%
nwork.loc[nwork.shorttitle.str.startswith('King--of the Khy', na = False)]
# Out:
#                         oldauthor         author  authordate  inferreddate  \
# docid
# mdp.39015009020440  Mundy, Talbot  Mundy, Talbot  1879-1940.          1916
#
#                     latestcomp datetype startdate enddate  \
# docid
# mdp.39015009020440        1916        s      1916
#
#                                      imprint imprintdate  \
# docid
# mdp.39015009020440  New York;A.L. Burt;c1916        1916
#
#                                           ...                         place  \
# docid                                     ...
# mdp.39015009020440                        ...                           nyu
#
#                    recordid instances allcopiesofwork copiesin25yrs  enumcron  \
# docid
# mdp.39015009020440   159838         1               2             2       NaN
#
#                    volnum                                              title  \
# docid
# mdp.39015009020440    NaN  King--of the Khyber rifles; | a romance of adv...
#
# ...

# %%
nwork.loc[nwork.shorttitle.str.startswith('Mary Barto', na = False)]
# Out:
#                             docid                    oldauthor  \
# 8662    uiuo.ark+=13960=t9z03hc07  Gaskell, Elizabeth Cleghorn
# 37508          mdp.39015033170104  Gaskell, Elizabeth Cleghorn
# 117142         coo.31924077744807  Gaskell, Elizabeth Cleghorn
#
#                              author  authordate  inferreddate  latestcomp  \
# 8662    Gaskell, Elizabeth Cleghorn  1810-1865.          1848        1848
# 37508   Gaskell, Elizabeth Cleghorn  1810-1865.          1902        1865
# 117142  Gaskell, Elizabeth Cleghorn  1810-1865.          1993        1865
#
#        datetype startdate enddate                           imprint  \
# 8662          s      1848             London;Chapman and Hall;1848.
# 37508         s      1902          London;Smith, Elder, & co.;1902.
# 117142        s      1993                 Halifax|Ryburn Pub.|1993.
#
#                          ...                    place recordid instances  \
# ...

# %%
work.loc[work.shorttitle.str.startswith('Bleak House', na = False)]
# Out:
#                     docid         oldauthor            author  authordate  \
# 47392  coo.31924013471804  Dickens, Charles  Dickens, Charles  1812-1870.
# 47393  coo.31924064973229  Dickens, Charles  Dickens, Charles  1812-1870.
# 76330    pst.000029717460  Dickens, Charles  Dickens, Charles  1812-1870.
#
#        inferreddate  latestcomp datetype startdate enddate  \
# 47392          1912        1870        s      1912
# 47393          1912        1870        s      1912
# 76330          1953        1870        s      1953
#
#                                                  imprint  \
# 47392                     London;Waverley Book Co.;1912?
# 47393                     London;Waverley Book Co.;1912?
# 76330  Garden City, N.Y.|International Collectors Lib...
#
#                             ...                        place  recordid  \
# 47392                       ...                          enk  11665516
# 47393                       ...                          enk  11665516
# ...

# %%
nwork.loc[nwork.shorttitle.str.startswith('Bleak', na = False)]
# Out:
#                             docid                            oldauthor  \
# 9833    uiuo.ark+=13960=t3tt5bm1x                     Dickens, Charles
# 9834    uiuo.ark+=13960=t9t15qw1s                     Dickens, Charles
# 9835    uiuo.ark+=13960=t19k51v83                     Dickens, Charles
# 9836    uiuo.ark+=13960=t2c830k3q                     Dickens, Charles
# 49440          coo.31924013471804                     Dickens, Charles
# 49441          coo.31924064973229                     Dickens, Charles
# 78564            pst.000029717460                     Dickens, Charles
# 87848          mdp.39015012976034  Tolstoy, Aleksey Nikolayevich, graf
# 117037         inu.30000035563315                          Cleary, Jon
#
#                                      author  authordate  inferreddate  \
# 9833                       Dickens, Charles  1812-1870.          1852
# 9834                       Dickens, Charles  1812-1870.          1852
# ...

# %%
manifest.loc[manifest.shorttitle.str.startswith('Bleak', na = False)]
# Out:
#                             docid                            oldauthor  \
# 20             mdp.39015014689247                     Dickens, Charles
# 370            inu.30000005050624                     Dickens, Charles
# 989           uiug.30112042034709                     Dickens, Charles
# 13435   uiuo.ark+=13960=t3tt5bm1x                     Dickens, Charles
# 13436   uiuo.ark+=13960=t9t15qw1s                     Dickens, Charles
# 13437   uiuo.ark+=13960=t19k51v83                     Dickens, Charles
# 13438   uiuo.ark+=13960=t2c830k3q                     Dickens, Charles
# 13651          inu.32000003256429                     Dickens, Charles
# 13688    uc2.ark+=13960=t47p8x024                     Dickens, Charles
# 19056          nyp.33433082246376                     Dickens, Charles
# 20944          nyp.33433074954375                     Dickens, Charles
# 21523          njp.32101045671631                     Dickens, Charles
# ...

# %%
manifest.shape
# Out:
# (176623, 25)

# %%
manifest.drop_duplicates(subset = 'docid', inplace = True)
manifest.shape
# Out:
# (176623, 25)

# %%
nwork.shape
# Out:
# (158320, 27)

# %%
nwork.drop_duplicates(subset = 'docid', inplace = True)
nwork.shape
# Out:
# (148265, 27)

# %%
work.shape
# Out:
# (135299, 27)

# %%
work.drop_duplicates(subset = 'docid', inplace = True)
work.shape
# Out:
# (135255, 27)

# %%
j = 'loc.ark+=13960=t6xw4zv8z	mdp.39015058674477	uc1.b3549874	mdp.39015005719250	miun.aca8482.0001.001	njp.32101045671623	nyp.33433082122429	nyp.33433082122437	uiuo.ark+=13960=t19k51v83	mdp.49015002936764	nyp.33433069279036	inu.30000005050624	mdp.39015073312624	pst.000005308965	pst.000044262266	pst.000003829073	njp.32101045671631	uc1.32106018847266	uc1.b4456975	uc1.b3549703	uiuo.ark+=13960=t2c830k3q	uc1.32106001932505	uc1.b3549673	pst.000029568314	inu.32000003256429	nyp.33433074954748	pst.000005308958	mdp.39076006604420	uiuo.ark+=13960=t3tt5bm1x	nyp.33433074954375	uiuo.ark+=13960=t9t15qw1s	nyp.33433082246376	pst.000007898396	uc1.32106014323304	mdp.39015014689247	pst.000004740728	uiug.30112042034709	uc2.ark+=13960=t47p8x024	nyp.33433076092943	osu.32435079772828'
bh = j.split('\t')
bh
# Out:
# ['loc.ark+=13960=t6xw4zv8z',
#  'mdp.39015058674477',
#  'uc1.b3549874',
#  'mdp.39015005719250',
#  'miun.aca8482.0001.001',
#  'njp.32101045671623',
#  'nyp.33433082122429',
#  'nyp.33433082122437',
#  'uiuo.ark+=13960=t19k51v83',
#  'mdp.49015002936764',
#  'nyp.33433069279036',
#  'inu.30000005050624',
#  'mdp.39015073312624',
#  'pst.000005308965',
#  'pst.000044262266',
#  'pst.000003829073',
#  'njp.32101045671631',
#  'uc1.32106018847266',
#  'uc1.b4456975',
#  'uc1.b3549703',
#  'uiuo.ark+=13960=t2c830k3q',
#  'uc1.32106001932505',
#  'uc1.b3549673',
#  'pst.000029568314',
#  'inu.32000003256429',
#  'nyp.33433074954748',
#  'pst.000005308958',
#  'mdp.39076006604420',
#  'uiuo.ark+=13960=t3tt5bm1x',
#  'nyp.33433074954375',
#  'uiuo.ark+=13960=t9t15qw1s',
#  'nyp.33433082246376',
#  'pst.000007898396',
#  'uc1.32106014323304',
#  'mdp.39015014689247',
#  'pst.000004740728',
#  'uiug.30112042034709',
#  'uc2.ark+=13960=t47p8x024',
#  'nyp.33433076092943',
# ...

# %%
manifest.loc[manifest.docid.isin(bh), :]
# Out:
#                             docid         oldauthor            author  \
# 20             mdp.39015014689247  Dickens, Charles  Dickens, Charles
# 370            inu.30000005050624  Dickens, Charles  Dickens, Charles
# 989           uiug.30112042034709  Dickens, Charles  Dickens, Charles
# 13435   uiuo.ark+=13960=t3tt5bm1x  Dickens, Charles  Dickens, Charles
# 13436   uiuo.ark+=13960=t9t15qw1s  Dickens, Charles  Dickens, Charles
# 13437   uiuo.ark+=13960=t19k51v83  Dickens, Charles  Dickens, Charles
# 13438   uiuo.ark+=13960=t2c830k3q  Dickens, Charles  Dickens, Charles
# 13651          inu.32000003256429  Dickens, Charles  Dickens, Charles
# 13688    uc2.ark+=13960=t47p8x024  Dickens, Charles  Dickens, Charles
# 19056          nyp.33433082246376  Dickens, Charles  Dickens, Charles
# 20944          nyp.33433074954375  Dickens, Charles  Dickens, Charles
# 21523          njp.32101045671631  Dickens, Charles  Dickens, Charles
# ...
