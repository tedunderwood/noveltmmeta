# %% [markdown]
# # Make popular subset

# %%
import pandas as pd

# %%
title = pd.read_csv('../titlemeta.tsv', sep = '\t', index_col = 'docid', low_memory = False)

# %%
frames = []

for floor in range(1800, 2010, 10):
    decade = title.loc[(title.latestcomp >= floor) & (title.latestcomp < (floor + 10)), : ]
    sample = decade.nlargest(100, 'copiesin25yrs')  
    frames.append(sample)

subset = pd.concat(frames)
subset.shape
# Out:
# (2100, 27)

# %%
subset.head()
# Out:
#                                         oldauthor                  author  \
# docid
# uiuo.ark+=13960=t7cr6hq4j     Hamilton, Elizabeth     Hamilton, Elizabeth
# uva.x000099740                Hamilton, Elizabeth     Hamilton, Elizabeth
# uiuo.ark+=13960=t0ks7d013     Hamilton, Elizabeth     Hamilton, Elizabeth
# nyp.33433074951595         Cuthbertson, Catherine  Cuthbertson, Catherine
# uiuo.ark+=13960=t6xw4rw1j  Cuthbertson, Catherine  Cuthbertson, Catherine
#
#                             authordate  inferreddate  latestcomp datetype  \
# docid
# uiuo.ark+=13960=t7cr6hq4j  1756?-1816.          1800        1800        s
# uva.x000099740             1756?-1816.          1800        1800        s
# uiuo.ark+=13960=t0ks7d013  1756?-1816.          1800        1800        s
# nyp.33433074951595                 NaN          1803        1803        s
# uiuo.ark+=13960=t6xw4rw1j          NaN          1803        1803        s
#
#                           startdate enddate  \
# docid
# uiuo.ark+=13960=t7cr6hq4j      1800
# uva.x000099740                 1800
# uiuo.ark+=13960=t0ks7d013      1800
# nyp.33433074951595             1803
# uiuo.ark+=13960=t6xw4rw1j      1803
#
#                                                                      imprint  \
# docid
# uiuo.ark+=13960=t7cr6hq4j  Bath;Printed by R. Cruttwell for G.G. and J. R...
# uva.x000099740             Bath;Printed by R. Cruttwell for G.G. and J. R...
# uiuo.ark+=13960=t0ks7d013  Bath;Printed by R. Cruttwell for G.G. and J. R...
# nyp.33433074951595               London;Printed for G. and J. Robinson;1803.
# uiuo.ark+=13960=t6xw4rw1j        London;Printed for G. and J. Robinson;1803.
#
#                           imprintdate               ...                \
# docid                                               ...
# uiuo.ark+=13960=t7cr6hq4j        1800               ...
# uva.x000099740                   1800               ...
# uiuo.ark+=13960=t0ks7d013        1800               ...
# nyp.33433074951595               1803               ...
# uiuo.ark+=13960=t6xw4rw1j        1803               ...
#
#                           recordid instances allcopiesofwork copiesin25yrs  \
# docid
# uiuo.ark+=13960=t7cr6hq4j  8721527         1              14            12
# uva.x000099740             8721527         2              14            12
# uiuo.ark+=13960=t0ks7d013  8721527         1              14            12
# nyp.33433074951595         8690976         2              12            12
# uiuo.ark+=13960=t6xw4rw1j  8690976         2              12            12
#
#                           enumcron  volnum                            title  \
# docid
# uiuo.ark+=13960=t7cr6hq4j      v.1     1.0   Memoirs of modern philosophers
# uva.x000099740                 v.2     2.0  Memoirs of modern philosophers.
# uiuo.ark+=13960=t0ks7d013      v.3     3.0   Memoirs of modern philosophers
# nyp.33433074951595            v. 1     1.0      Romance of the Pyrenees ...
# uiuo.ark+=13960=t6xw4rw1j      v.2     2.0          Romance of the Pyrenees
#
#                            parttitle  earlyedition  \
# docid
# uiuo.ark+=13960=t7cr6hq4j        NaN          True
# uva.x000099740                   NaN          True
# uiuo.ark+=13960=t0ks7d013        NaN          True
# nyp.33433074951595               NaN          True
# uiuo.ark+=13960=t6xw4rw1j        NaN          True
#
#                                                shorttitle
# docid
# uiuo.ark+=13960=t7cr6hq4j  Memoirs of modern philosophers
# uva.x000099740             Memoirs of modern philosophers
# uiuo.ark+=13960=t0ks7d013  Memoirs of modern philosophers
# nyp.33433074951595                Romance of the Pyrenees
# uiuo.ark+=13960=t6xw4rw1j         Romance of the Pyrenees
#
# [5 rows x 27 columns]

# %%
subset.to_csv('most_popular_subset.tsv', sep = '\t', index_label = 'docid')
